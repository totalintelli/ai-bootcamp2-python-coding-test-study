# %% [markdown]
# ![image.png](attachment:0f137587-c4d4-4aef-b5e8-deaa9ef3f20d.png)

# %%
input_list = list(map(int,input().split()))
res = (input_list[0] ** input_list[1]) % input_list[2]
print(res)
# Out:
# 4
