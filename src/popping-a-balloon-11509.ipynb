# %% [markdown]
# ![image.png](attachment:a949d559-9466-46f1-9b75-1ec138488480.png)

# %%
inputs = map(int, (input().split()))
print(type(inputs))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 inputs = int(map(input().split()))
#       2 print(type(inputs))
#
# TypeError: map() must have at least two arguments.
